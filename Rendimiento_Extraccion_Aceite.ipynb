# %% [markdown]
# <a href="https://colab.research.google.com/github/valerinruiz13-pixel/Notebook-Agro-2026_1/blob/main/Rendimiento_Extraccion_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
#
# $$pa = lt * 0.92$$
#
# $$r=(pa /pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float).(pr)
# Solicitar los litros de aceite obtenidos (Tipo float).(lt)
nombre = input("Ingrese el nombre del lote de producción: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese los litros de aceite obtenidos: "))

#PROCESO: calcular el peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa / pr) * 100


#SALIDA: informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote de producción: el perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese los litros de aceite obtenidos: 200
# El rendimiento del lote el perico es del 18.4 %

# %% [markdown]
# A continuación, se explica cada línea del código para el problema de Control de Rendimiento en Extracción de Aceite:
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float).(pr)
# # Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# nombre = input("Ingrese el nombre del lote de producción: ")
# ```
# *   `nombre = input("Ingrese el nombre del lote de producción: ")`: Esta línea le pide al usuario que ingrese el nombre del lote de producción. El texto entre comillas es lo que se muestra al usuario. La entrada del usuario se almacena como una cadena de texto (string) en la variable `nombre`.
#
# ```python
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# *   `pr = float(input("Ingrese el peso de los racimos en kg: "))`: Esta línea solicita al usuario que ingrese el peso de los racimos de fruta fresca (RFF) en kilogramos. La función `input()` recoge la entrada como texto, y `float()` la convierte en un número decimal (float) antes de almacenarla en la variable `pr`.
#
# ```python
# lt = float(input("Ingrese los litros de aceite obtenidos: "))
# ```
# *   `lt = float(input("Ingrese los litros de aceite obtenidos: "))`: Similar a la línea anterior, esta línea pide al usuario que ingrese la cantidad de aceite crudo obtenida en litros. La entrada se convierte a un número decimal (float) y se guarda en la variable `lt`.
#
# ```python
# #PROCESO: calcular el peso del aceite (pa) y el rendimiento (r)
# pa = lt * 0.92
# ```
# *   `pa = lt * 0.92`: Esta línea calcula el peso del aceite (`pa`). Multiplica los litros de aceite obtenidos (`lt`) por la densidad aproximada del aceite (0.92 kg/L). El resultado se almacena en la variable `pa`.
#
# ```python
# r = (pa / pr) * 100
# ```
# *   `r = (pa / pr) * 100`: Esta línea calcula el rendimiento de extracción (`r`). Divide el peso del aceite (`pa`) por el peso de los racimos (`pr`) y luego multiplica el resultado por 100 para expresarlo como un porcentaje. El valor se guarda en la variable `r`.
#
# ```python
# #SALIDA: informar el rendimiento del lote
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# *   `print("El rendimiento del lote", nombre, "es del", r, "%")`: Esta línea imprime el resultado final en la consola. Combina varias cadenas de texto con los valores de las variables `nombre` y `r` para mostrar un mensaje informativo sobre el rendimiento del lote de producción.
